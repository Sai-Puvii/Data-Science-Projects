# %% [markdown]
# # Answering Business Questions using SQL

# %% [markdown]
# We will use the chinook database for this project. The chinook database is provided as a SQLite database file called chinook.db.

# %% [markdown]
# ![](chinook-schema.svg)

# %%
from sqlalchemy.engine import create_engine
import sqlite3
from pandas.io import sql
import subprocess
# %reload_ext sql

# %%
# %sql sqlite:///chinook.db
# Out:
# 'Connected: @chinook.db'

# %% [markdown]
# ## Overview of the Data

# %% [markdown]
# Let us start by getting familiar with the data

# %%
# %%sql
# SELECT
#      name,
#      type
# FROM sqlite_master
# WHERE type IN ('table','view');
# Out:
#  * sqlite:///chinook.db
# Done.
# [('albums', 'table'),
#  ('sqlite_sequence', 'table'),
#  ('artists', 'table'),
#  ('customers', 'table'),
#  ('employees', 'table'),
#  ('genres', 'table'),
#  ('invoices', 'table'),
#  ('invoice_items', 'table'),
#  ('media_types', 'table'),
#  ('playlists', 'table'),
#  ('playlist_track', 'table'),
#  ('tracks', 'table'),
#  ('sqlite_stat1', 'table')]

# %% [markdown]
# ## Selecting Albums to Purchase

# %% [markdown]
# The Chinook record store has just signed a deal with a new record label, and the task is selecting the first three albums that will be added to the store, from a list of four. All four albums are by artists that do not have any tracks in the store right now - we have the artist names, and the genre of the music they produce.
# |Artist | Genre |
# |:----------:|:----------:|
# |Regal | Hip-hop|
# |Red Tone | Punk|
# |Meteor and The Girls | Pop|
# |Slim Jim Bites |Blues|

# %% [markdown]
# The record label specializes in artists from the USA, and they have given Chinook some money to advertise new albums in the USA, so we are interested in finding out which genres sell the best in the USA.

# %%
# %%sql
# WITH genre_sold_usa AS
# (
#     SELECT
#        g.Name genre,
#        SUM(il.Quantity) num_tracks
#       FROM genres g
#       INNER JOIN tracks t on t.GenreId = g.GenreId
#       INNER JOIN invoice_items il on il.TrackId = t.TrackId
#       INNER JOIN invoices i on i.InvoiceId = il.InvoiceId
#       INNER JOIN customers c on c.CustomerId = i.CustomerId
#      WHERE c.country = 'USA'
#      GROUP BY 1
#      ORDER BY 2
# )
#
# SELECT
#     gsu.genre Genre,
#     gsu.num_tracks abs_tracks
# FROM genre_sold_usa gsu;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Science Fiction', 1),
#  ('Easy Listening', 3),
#  ('Rock And Roll', 3),
#  ('Heavy Metal', 4),
#  ('Hip Hop/Rap', 4),
#  ('Soundtrack', 4),
#  ('Alternative', 5),
#  ('Pop', 5),
#  ('Sci Fi & Fantasy', 5),
#  ('Drama', 6),
#  ('Reggae', 6),
#  ('Bossa Nova', 7),
#  ('Classical', 8),
#  ('Comedy', 8),
#  ('R&B/Soul', 12),
#  ('TV Shows', 14),
#  ('Blues', 15),
#  ('Jazz', 22),
#  ('Alternative & Punk', 50),
#  ('Metal', 64),
#  ('Latin', 91),
#  ('Rock', 157)]

# %% [markdown]
# From the above, it can be said that Rock sells best in the USA, with a total of 157 tracks sold so far. However, Rock is not available in the record label.
# Below is a list of the number of tracks sold according to the genres available in the record label, in a decreasing order, on the basis of no. of tracks sold.
# 1. Alternative & Punk - 50
# 2. Blues - 15
# 3. Pop - 5
# 4. Hip Hop/Rap - 4

# %% [markdown]
# Based on the list, we should purchase the albums of artists Red Tone, Slim Jim Bites, and Meteor and The Girls respectively, since their genres sell well.

# %% [markdown]
# ## Analyzing Employee Sales Performace

# %% [markdown]
# Each customer for the Chinook store gets assigned to a sales support agent within the company when they first make a purchase. We have been asked to analyze the purchases of customers belonging to each employee to see if any sales support agent is performing either better or worse than the others.

# %%
# %%sql
#
# SELECT
#    e.FirstName || ' ' || e.LastName name,
#    e.Title Title,
#    e.BirthDate Birth_Date,
#    e.HireDate Hire_Date,
#    max(i.InvoiceDate) Latest_invoice_date,
#    ROUND(SUM(i.Total), 2) amount_sales
#   FROM employees e
#   LEFT JOIN customers c on e.EmployeeId = c.SupportRepId
#   LEFT JOIN invoices i on i.CustomerId = c.CustomerId
#
#   WHERE Title = 'Sales Support Agent'
#   GROUP BY 1
#   ORDER BY 2
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Jane Peacock', 'Sales Support Agent', '1973-08-29 00:00:00', '2002-04-01 00:00:00', '2013-12-22 00:00:00', 833.04),
#  ('Margaret Park', 'Sales Support Agent', '1947-09-19 00:00:00', '2003-05-03 00:00:00', '2013-12-09 00:00:00', 775.4),
#  ('Steve Johnson', 'Sales Support Agent', '1965-03-03 00:00:00', '2003-10-17 00:00:00', '2013-12-05 00:00:00', 720.16)]

# %% [markdown]
# ## Analyzing Sales by Country

# %% [markdown]
# The next task is to analyze the sales data for customers from each country. The country value from customers table will be used for this analysis, and ignore the country from the billing address in the invoice table.

# %% [markdown]
# We should calculate data for each country on the
# - total number of customers
# - total value of sales
# - average value of sales per customer
# - average order value

# %% [markdown]
# Since there are a number of countries with only one customer, these customers should be grouped as "Other" in the analysis.

# %%
# %%sql
#
# WITH no_of_cstmrs AS
# (
#     SELECT
#        country Country,
#        count(FirstName) No_of_customers
#      FROM customers
#       GROUP BY 1
#       ORDER BY 2 DESC
# )
#
# SELECT * FROM no_of_cstmrs
# Out:
#  * sqlite:///chinook.db
# Done.
# [('USA', 13),
#  ('Canada', 8),
#  ('France', 5),
#  ('Brazil', 5),
#  ('Germany', 4),
#  ('United Kingdom', 3),
#  ('Portugal', 2),
#  ('India', 2),
#  ('Czech Republic', 2),
#  ('Sweden', 1),
#  ('Spain', 1),
#  ('Poland', 1),
#  ('Norway', 1),
#  ('Netherlands', 1),
#  ('Italy', 1),
#  ('Ireland', 1),
#  ('Hungary', 1),
#  ('Finland', 1),
#  ('Denmark', 1),
#  ('Chile', 1),
#  ('Belgium', 1),
#  ('Austria', 1),
#  ('Australia', 1),
#  ('Argentina', 1)]

# %%
# %%sql
#
# WITH no_of_cstmrs AS
# (
#     SELECT
#        country Country,
#        count(FirstName) No_of_customers
#      FROM customers
#       GROUP BY 1
#       ORDER BY 2 DESC
# ),
#
# total_sales_value AS
# (SELECT c.country Country,
#        ROUND(SUM(i.total), 2) Total_Value_Sales,
#        ROUND(AVG(i.total), 2) Avg_Order_Value,
#        ROUND(SUM(i.total)/(SELECT COUNT(DISTINCT(CustomerId)) FROM invoices), 2) Avg_Sales_Value_per_Customer
#
#  FROM customers c
# INNER JOIN invoices i ON i.CustomerId = c.CustomerId
# GROUP BY 1
# ORDER BY 2 DESC),
#
# sales_data_1 AS
# (SELECT noc.Country,
#        noc.No_of_customers,
#        tsv.Total_Value_Sales,
#        tsv.Avg_Sales_Value_per_Customer,
#        tsv.Avg_Order_Value
#   FROM no_of_cstmrs noc
# INNER JOIN total_sales_value tsv ON tsv.Country=noc.Country
#  WHERE noc.No_of_customers > 1),
#
# sales_data_2 AS
# (SELECT CASE
#        WHEN noc.No_of_customers=1 THEN "Others"
#        END AS
#        Country,
#        noc.No_of_customers,
#        ROUND(AVG(tsv.Total_Value_Sales),2) Total_Value_Sales,
#        ROUND(AVG(tsv.Avg_Sales_Value_per_Customer),2) AVG_Sales_Value_per_Customer,
#        ROUND(AVG(tsv.Avg_Order_Value),2) AVG_Order_Value
#   FROM no_of_cstmrs noc
# INNER JOIN total_sales_value tsv ON tsv.Country=noc.Country
#  WHERE noc.No_of_customers = 1),
#
# total_sales_data AS
# (SELECT *
# FROM sales_data_1
# UNION
# SELECT *
# FROM sales_data_2)
#
# SELECT *
#   FROM total_sales_data
# ORDER BY 3 DESC;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('USA', 13, 523.06, 8.87, 5.75),
#  ('Canada', 8, 303.96, 5.15, 5.43),
#  ('France', 5, 195.1, 3.31, 5.57),
#  ('Brazil', 5, 190.1, 3.22, 5.43),
#  ('Germany', 4, 156.48, 2.65, 5.59),
#  ('United Kingdom', 3, 112.86, 1.91, 5.37),
#  ('Czech Republic', 2, 90.24, 1.53, 6.45),
#  ('Portugal', 2, 77.24, 1.31, 5.52),
#  ('India', 2, 75.26, 1.28, 5.79),
#  ('Others', 1, 40.29, 0.68, 5.75)]

# %% [markdown]
# ## Albums vs Individual Tracks

# %% [markdown]
# The Chinook store is setup in a way that allows customer to make purchases in one of the two ways:
# - purchase a whole album
# - purchase a collection of one or more individual tracks

# %% [markdown]
# The store does not let customers purchase a whole album, and then add individuals tracks to the same purchase (unless they do that by choosing each track manually). When customers purchase albums they are charged the same price as if they had purchased each of those tracks separately.

# %% [markdown]
# Management are currently considering changing their purchase strategy to save money. The strategy considered is to purchase only the most popular tracks from each album from record companies, instead of purchasing every track from an album.

# %% [markdown]
# We have to find out what percentage of purchases are individual tracks vs whole albums, so that management can use this data to understand the effect this decision might have on overall revenue.

# %% [markdown]
# It is quite common to have "edge cases" which prevent us from getting a 100% accurate answer to the question. In this instance, we have two edge cases to consider:
# - Albums that have only one or two tracks are likely to be purchased by customers as part of a collection of individual tracks.
# - Customers may decide to manually select every track from an album, and then add a few individual tracks from other albums to the purchase.

# %% [markdown]
# In the first case, since the analysis is concerned with maximizing revenue, we can safely ignore albums consisting of a few tracks. The company has previously done analysis to confirm that the second case does not happen often, so we can ignore this also.

# %% [markdown]
# In order to answer the question, we are going to have to identify whether each invoice has all the tracks from an album. We can do this by getting the list of tracks from an invoice and comparing it to the list of tracks from an album. We can find the album to compare the purchase to by looking up the album that one of the purchased tracks belongs to. It doesn't matter which track we pick, since if it's an album purchase, that album will be same for all tracks.

# %%
# %%sql
#
# SELECT max(InvoiceId) total_invoice
#     FROM invoice_items;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(412,)]

# %% [markdown]
# From the above table we observe that there are a total of 412 invoices. Further, we can compare the tracks from invoice with that of albums

# %%
# %%sql
#
# WITH com_prchs AS
# (
#     SELECT
#        il.InvoiceId invoice_id,
#        il.TrackId Prchs_tracks,
#        t.AlbumId album_id
#       FROM tracks t
#     INNER JOIN invoice_items il on il.TrackId = t.TrackId
#     ORDER BY 1
# )
#
# SELECT *
#  FROM com_prchs;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 2, 2),
#  (1, 4, 3),
#  (2, 6, 1),
#  (2, 8, 1),
#  (2, 10, 1),
#  (2, 12, 1),
#  (3, 16, 4),
#  (3, 20, 4),
#  (3, 24, 5),
#  (3, 28, 5),
#  (3, 32, 5),
#  (3, 36, 5),
#  (4, 42, 6),
#  (4, 48, 6),
#  (4, 54, 7),
#  (4, 60, 7),
#  (4, 66, 8),
#  (4, 72, 8),
#  (4, 78, 9),
#  (4, 84, 9),
#  (4, 90, 10),
#  (5, 99, 11),
#  (5, 108, 11),
#  (5, 117, 12),
#  (5, 126, 13),
#  (5, 135, 14),
#  (5, 144, 15),
#  (5, 153, 16),
#  (5, 162, 17),
#  (5, 171, 18),
#  (5, 180, 18),
#  (5, 189, 19),
#  (5, 198, 20),
#  (5, 207, 21),
#  (5, 216, 21),
#  (6, 230, 23),
#  (7, 231, 23),
#  (7, 232, 23),
#  (8, 234, 23),
#  (8, 236, 23),
#  (9, 238, 23),
#  (9, 240, 23),
#  (9, 242, 23),
#  (9, 244, 23),
#  (10, 248, 24),
#  (10, 252, 24),
#  (10, 256, 24),
#  (10, 260, 24),
#  (10, 264, 24),
#  (10, 268, 24),
#  (11, 274, 25),
#  (11, 280, 25),
#  (11, 286, 26),
#  (11, 292, 26),
#  (11, 298, 26),
#  (11, 304, 27),
#  (11, 310, 27),
#  (11, 316, 28),
#  (11, 322, 28),
#  (12, 331, 29),
#  (12, 340, 30),
#  (12, 349, 30),
#  (12, 358, 31),
#  (12, 367, 32),
#  (12, 376, 33),
#  (12, 385, 33),
#  (12, 394, 34),
#  (12, 403, 34),
#  (12, 412, 35),
#  (12, 421, 36),
#  (12, 430, 36),
#  (12, 439, 37),
#  (12, 448, 37),
#  (13, 462, 38),
#  (14, 463, 38),
#  (14, 464, 38),
#  (15, 466, 38),
#  (15, 468, 39),
#  (16, 470, 39),
#  (16, 472, 39),
#  (16, 474, 39),
#  (16, 476, 39),
#  (17, 480, 39),
#  (17, 484, 39),
#  (17, 488, 39),
#  (17, 492, 40),
#  (17, 496, 40),
#  (17, 500, 40),
#  (18, 506, 41),
#  (18, 512, 41),
#  (18, 518, 23),
#  (18, 524, 23),
#  (18, 530, 42),
#  (18, 536, 42),
#  (18, 542, 42),
#  (18, 548, 43),
#  (18, 554, 44),
#  (19, 563, 45),
#  (19, 572, 46),
#  (19, 581, 46),
#  (19, 590, 47),
#  (19, 599, 48),
#  (19, 608, 48),
#  (19, 617, 49),
#  (19, 626, 51),
#  (19, 635, 51),
#  (173, 2209, 182),
#  (173, 2218, 141),
#  (173, 2227, 141),
#  (173, 2236, 183),
#  (173, 2245, 184),
#  (173, 2254, 185),
#  (173, 2263, 185),
#  (173, 2272, 186),
#  (173, 2281, 186),
#  (174, 2295, 188),
#  (175, 2296, 189),
#  (175, 2297, 189),
#  (176, 2299, 189),
#  (176, 2301, 189),
#  (177, 2303, 189),
#  (177, 2305, 189),
#  (177, 2307, 189),
#  (177, 2309, 189),
#  (178, 2313, 187),
#  (178, 2317, 187),
#  (178, 2321, 190),
#  (178, 2325, 190),
#  (178, 2329, 190),
#  (178, 2333, 190),
#  (179, 2339, 191),
#  (179, 2345, 192),
#  (179, 2351, 192),
#  (179, 2357, 192),
#  (179, 2363, 193),
#  (179, 2369, 193),
#  (179, 2375, 194),
#  (179, 2381, 194),
#  (179, 2387, 194),
#  (180, 2396, 195),
#  (180, 2405, 195),
#  (180, 2414, 196),
#  (180, 2423, 197),
#  (180, 2432, 198),
#  (180, 2441, 141),
#  (180, 2450, 199),
#  (180, 2459, 199),
#  (180, 2468, 200),
#  (180, 2477, 201),
#  (180, 2486, 201),
#  (180, 2495, 202),
#  (180, 2504, 202),
#  (180, 2513, 203),
#  (181, 2527, 204),
#  (182, 2528, 204),
#  (182, 2529, 204),
#  (183, 2531, 204),
#  (183, 2533, 205),
#  (184, 2535, 205),
#  (184, 2537, 205),
#  (184, 2539, 205),
#  (184, 2541, 205),
#  (185, 2545, 206),
#  (185, 2549, 206),
#  (185, 2553, 206),
#  (185, 2557, 207),
#  (185, 2561, 207),
#  (185, 2565, 208),
#  ...]

# %% [markdown]
# From the above table it can be observed that if the tracks belonging to each distinct invoice belongs to the same album it is an Album Purchase. If these tracks belong to different albums it is Non Albu Purchase.

# %% [markdown]
# Below, we can categorize these invoices into Album and Non Album Purchase. This can be done by counting the number of distinct albums belonging to each invoice. Then we compare the Distinct Albums and Number of Albums belonging to each invoice.

# %%
# %%sql
#
# WITH com_prchs AS
# (
#     SELECT
#        il.InvoiceId invoice_id,
#        il.TrackId Prchs_tracks,
#        t.AlbumId album_id
#       FROM tracks t
#     INNER JOIN invoice_items il on il.TrackId = t.TrackId
#     ORDER BY 1
# )
#
# SELECT
#    invoice_id,
#    COUNT(DISTINCT(album_id)) Distinct_album_id,
#    COUNT(album_id) No_of_album_id,
#    CASE
#    WHEN COUNT(album_id) - COUNT(DISTINCT(album_id)) <= 2 THEN "Non Album Purchase"
#    ELSE "Album Purchase"
#    END AS Category
#   FROM com_prchs
#  GROUP BY 1;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 2, 2, 'Non Album Purchase'),
#  (2, 1, 4, 'Album Purchase'),
#  (3, 2, 6, 'Album Purchase'),
#  (4, 5, 9, 'Album Purchase'),
#  (5, 11, 14, 'Album Purchase'),
#  (6, 1, 1, 'Non Album Purchase'),
#  (7, 1, 2, 'Non Album Purchase'),
#  (8, 1, 2, 'Non Album Purchase'),
#  (9, 1, 4, 'Album Purchase'),
#  (10, 1, 6, 'Album Purchase'),
#  (11, 4, 9, 'Album Purchase'),
#  (12, 9, 14, 'Album Purchase'),
#  (13, 1, 1, 'Non Album Purchase'),
#  (14, 1, 2, 'Non Album Purchase'),
#  (15, 2, 2, 'Non Album Purchase'),
#  (16, 1, 4, 'Album Purchase'),
#  (17, 2, 6, 'Album Purchase'),
#  (18, 5, 9, 'Album Purchase'),
#  (19, 9, 14, 'Album Purchase'),
#  (20, 1, 1, 'Non Album Purchase'),
#  (21, 1, 2, 'Non Album Purchase'),
#  (22, 1, 2, 'Non Album Purchase'),
#  (23, 1, 4, 'Album Purchase'),
#  (24, 3, 6, 'Album Purchase'),
#  (25, 7, 9, 'Non Album Purchase'),
#  (26, 11, 14, 'Album Purchase'),
#  (27, 1, 1, 'Non Album Purchase'),
#  (28, 1, 2, 'Non Album Purchase'),
#  (29, 1, 2, 'Non Album Purchase'),
#  (30, 2, 4, 'Non Album Purchase'),
#  (31, 3, 6, 'Album Purchase'),
#  (32, 5, 9, 'Album Purchase'),
#  (33, 8, 14, 'Album Purchase'),
#  (34, 1, 1, 'Non Album Purchase'),
#  (35, 1, 2, 'Non Album Purchase'),
#  (36, 1, 2, 'Non Album Purchase'),
#  (37, 1, 4, 'Album Purchase'),
#  (38, 2, 6, 'Album Purchase'),
#  (39, 5, 9, 'Album Purchase'),
#  (40, 12, 14, 'Non Album Purchase'),
#  (41, 1, 1, 'Non Album Purchase'),
#  (42, 1, 2, 'Non Album Purchase'),
#  (43, 2, 2, 'Non Album Purchase'),
#  (44, 1, 4, 'Album Purchase'),
#  (45, 2, 6, 'Album Purchase'),
#  (46, 5, 9, 'Album Purchase'),
#  (47, 11, 14, 'Album Purchase'),
#  (48, 1, 1, 'Non Album Purchase'),
#  (49, 1, 2, 'Non Album Purchase'),
#  (50, 2, 2, 'Non Album Purchase'),
#  (51, 2, 4, 'Non Album Purchase'),
#  (52, 3, 6, 'Album Purchase'),
#  (53, 4, 9, 'Album Purchase'),
#  (54, 10, 14, 'Album Purchase'),
#  (55, 1, 1, 'Non Album Purchase'),
#  (56, 1, 2, 'Non Album Purchase'),
#  (57, 1, 2, 'Non Album Purchase'),
#  (58, 1, 4, 'Album Purchase'),
#  (59, 3, 6, 'Album Purchase'),
#  (60, 5, 9, 'Album Purchase'),
#  (61, 9, 14, 'Album Purchase'),
#  (62, 1, 1, 'Non Album Purchase'),
#  (63, 1, 2, 'Non Album Purchase'),
#  (64, 1, 2, 'Non Album Purchase'),
#  (65, 4, 4, 'Non Album Purchase'),
#  (66, 2, 6, 'Album Purchase'),
#  (67, 5, 9, 'Album Purchase'),
#  (68, 10, 14, 'Album Purchase'),
#  (69, 1, 1, 'Non Album Purchase'),
#  (70, 1, 2, 'Non Album Purchase'),
#  (71, 1, 2, 'Non Album Purchase'),
#  (72, 1, 4, 'Album Purchase'),
#  (73, 2, 6, 'Album Purchase'),
#  (74, 4, 9, 'Album Purchase'),
#  (75, 10, 14, 'Album Purchase'),
#  (76, 1, 1, 'Non Album Purchase'),
#  (77, 1, 2, 'Non Album Purchase'),
#  (78, 1, 2, 'Non Album Purchase'),
#  (79, 1, 4, 'Album Purchase'),
#  (80, 3, 6, 'Album Purchase'),
#  (81, 4, 9, 'Album Purchase'),
#  (82, 9, 14, 'Album Purchase'),
#  (83, 1, 1, 'Non Album Purchase'),
#  (84, 1, 2, 'Non Album Purchase'),
#  (85, 1, 2, 'Non Album Purchase'),
#  (86, 1, 4, 'Album Purchase'),
#  (87, 3, 6, 'Album Purchase'),
#  (88, 4, 9, 'Album Purchase'),
#  (89, 8, 14, 'Album Purchase'),
#  (90, 1, 1, 'Non Album Purchase'),
#  (91, 1, 2, 'Non Album Purchase'),
#  (92, 1, 2, 'Non Album Purchase'),
#  (93, 2, 4, 'Non Album Purchase'),
#  (94, 3, 6, 'Album Purchase'),
#  (95, 5, 9, 'Album Purchase'),
#  (96, 9, 14, 'Album Purchase'),
#  (97, 1, 1, 'Non Album Purchase'),
#  (98, 1, 2, 'Non Album Purchase'),
#  (99, 2, 2, 'Non Album Purchase'),
#  (100, 1, 4, 'Album Purchase'),
#  (101, 2, 6, 'Album Purchase'),
#  (102, 4, 9, 'Album Purchase'),
#  (103, 11, 14, 'Album Purchase'),
#  (104, 1, 1, 'Non Album Purchase'),
#  (105, 2, 2, 'Non Album Purchase'),
#  (106, 2, 2, 'Non Album Purchase'),
#  (107, 4, 4, 'Non Album Purchase'),
#  (108, 4, 6, 'Non Album Purchase'),
#  (109, 5, 9, 'Album Purchase'),
#  (110, 10, 14, 'Album Purchase'),
#  (111, 1, 1, 'Non Album Purchase'),
#  (112, 1, 2, 'Non Album Purchase'),
#  (113, 1, 2, 'Non Album Purchase'),
#  (114, 1, 4, 'Album Purchase'),
#  (115, 2, 6, 'Album Purchase'),
#  (116, 4, 9, 'Album Purchase'),
#  (117, 10, 14, 'Album Purchase'),
#  (118, 1, 1, 'Non Album Purchase'),
#  (119, 1, 2, 'Non Album Purchase'),
#  (120, 1, 2, 'Non Album Purchase'),
#  (121, 1, 4, 'Album Purchase'),
#  (122, 2, 6, 'Album Purchase'),
#  (123, 5, 9, 'Album Purchase'),
#  (124, 10, 14, 'Album Purchase'),
#  (125, 1, 1, 'Non Album Purchase'),
#  (126, 1, 2, 'Non Album Purchase'),
#  (127, 1, 2, 'Non Album Purchase'),
#  (128, 1, 4, 'Album Purchase'),
#  (129, 2, 6, 'Album Purchase'),
#  (130, 5, 9, 'Album Purchase'),
#  (131, 11, 14, 'Album Purchase'),
#  (132, 1, 1, 'Non Album Purchase'),
#  (133, 1, 2, 'Non Album Purchase'),
#  (134, 2, 2, 'Non Album Purchase'),
#  (135, 1, 4, 'Album Purchase'),
#  (136, 3, 6, 'Album Purchase'),
#  (137, 5, 9, 'Album Purchase'),
#  (138, 10, 14, 'Album Purchase'),
#  (139, 1, 1, 'Non Album Purchase'),
#  (140, 1, 2, 'Non Album Purchase'),
#  (141, 1, 2, 'Non Album Purchase'),
#  (142, 2, 4, 'Non Album Purchase'),
#  (143, 2, 6, 'Album Purchase'),
#  (144, 5, 9, 'Album Purchase'),
#  (145, 12, 14, 'Non Album Purchase'),
#  (146, 1, 1, 'Non Album Purchase'),
#  (147, 1, 2, 'Non Album Purchase'),
#  (148, 1, 2, 'Non Album Purchase'),
#  (149, 2, 4, 'Non Album Purchase'),
#  (150, 3, 6, 'Album Purchase'),
#  (151, 5, 9, 'Album Purchase'),
#  (152, 9, 14, 'Album Purchase'),
#  (153, 1, 1, 'Non Album Purchase'),
#  (154, 1, 2, 'Non Album Purchase'),
#  (155, 1, 2, 'Non Album Purchase'),
#  (156, 2, 4, 'Non Album Purchase'),
#  (157, 4, 6, 'Non Album Purchase'),
#  (158, 6, 9, 'Album Purchase'),
#  (159, 10, 14, 'Album Purchase'),
#  (160, 1, 1, 'Non Album Purchase'),
#  (161, 1, 2, 'Non Album Purchase'),
#  (162, 1, 2, 'Non Album Purchase'),
#  (163, 1, 4, 'Album Purchase'),
#  (164, 3, 6, 'Album Purchase'),
#  (165, 5, 9, 'Album Purchase'),
#  (166, 9, 14, 'Album Purchase'),
#  (167, 1, 1, 'Non Album Purchase'),
#  (168, 2, 2, 'Non Album Purchase'),
#  (169, 1, 2, 'Non Album Purchase'),
#  (170, 2, 4, 'Non Album Purchase'),
#  (171, 4, 6, 'Non Album Purchase'),
#  (172, 5, 9, 'Album Purchase'),
#  (173, 10, 14, 'Album Purchase'),
#  (174, 1, 1, 'Non Album Purchase'),
#  (175, 1, 2, 'Non Album Purchase'),
#  (176, 1, 2, 'Non Album Purchase'),
#  (177, 1, 4, 'Album Purchase'),
#  (178, 2, 6, 'Album Purchase'),
#  (179, 4, 9, 'Album Purchase'),
#  (180, 10, 14, 'Album Purchase'),
#  (181, 1, 1, 'Non Album Purchase'),
#  (182, 1, 2, 'Non Album Purchase'),
#  (183, 2, 2, 'Non Album Purchase'),
#  (184, 1, 4, 'Album Purchase'),
#  (185, 3, 6, 'Album Purchase'),
#  (186, 5, 9, 'Album Purchase'),
#  (187, 9, 14, 'Album Purchase'),
#  (188, 1, 1, 'Non Album Purchase'),
#  (189, 1, 2, 'Non Album Purchase'),
#  (190, 1, 2, 'Non Album Purchase'),
#  (191, 1, 4, 'Album Purchase'),
#  (192, 2, 6, 'Album Purchase'),
#  (193, 3, 9, 'Album Purchase'),
#  (194, 7, 14, 'Album Purchase'),
#  (195, 1, 1, 'Non Album Purchase'),
#  (196, 1, 2, 'Non Album Purchase'),
#  (197, 1, 2, 'Non Album Purchase'),
#  (198, 2, 4, 'Non Album Purchase'),
#  (199, 3, 6, 'Album Purchase'),
#  (200, 5, 9, 'Album Purchase'),
#  (201, 8, 14, 'Album Purchase'),
#  (202, 1, 1, 'Non Album Purchase'),
#  (203, 2, 2, 'Non Album Purchase'),
#  (204, 1, 2, 'Non Album Purchase'),
#  (205, 1, 4, 'Album Purchase'),
#  (206, 2, 6, 'Album Purchase'),
#  (207, 4, 9, 'Album Purchase'),
#  (208, 11, 14, 'Album Purchase'),
#  (209, 1, 1, 'Non Album Purchase'),
#  (210, 1, 2, 'Non Album Purchase'),
#  (211, 1, 2, 'Non Album Purchase'),
#  (212, 2, 4, 'Non Album Purchase'),
#  (213, 5, 6, 'Non Album Purchase'),
#  (214, 6, 9, 'Album Purchase'),
#  (215, 11, 14, 'Album Purchase'),
#  (216, 1, 1, 'Non Album Purchase'),
#  (217, 1, 2, 'Non Album Purchase'),
#  (218, 1, 2, 'Non Album Purchase'),
#  (219, 2, 4, 'Non Album Purchase'),
#  (220, 2, 6, 'Album Purchase'),
#  (221, 3, 9, 'Album Purchase'),
#  (222, 9, 14, 'Album Purchase'),
#  (223, 1, 1, 'Non Album Purchase'),
#  (224, 1, 2, 'Non Album Purchase'),
#  (225, 1, 2, 'Non Album Purchase'),
#  (226, 1, 4, 'Album Purchase'),
#  (227, 2, 6, 'Album Purchase'),
#  (228, 4, 9, 'Album Purchase'),
#  (229, 10, 14, 'Album Purchase'),
#  (230, 1, 1, 'Non Album Purchase'),
#  (231, 1, 2, 'Non Album Purchase'),
#  (232, 1, 2, 'Non Album Purchase'),
#  (233, 2, 4, 'Non Album Purchase'),
#  (234, 2, 6, 'Album Purchase'),
#  (235, 4, 9, 'Album Purchase'),
#  (236, 13, 14, 'Non Album Purchase'),
#  (237, 1, 1, 'Non Album Purchase'),
#  (238, 1, 2, 'Non Album Purchase'),
#  (239, 1, 2, 'Non Album Purchase'),
#  (240, 2, 4, 'Non Album Purchase'),
#  (241, 2, 6, 'Album Purchase'),
#  (242, 4, 9, 'Album Purchase'),
#  (243, 9, 14, 'Album Purchase'),
#  (244, 1, 1, 'Non Album Purchase'),
#  (245, 1, 2, 'Non Album Purchase'),
#  (246, 1, 2, 'Non Album Purchase'),
#  (247, 2, 4, 'Non Album Purchase'),
#  (248, 3, 6, 'Album Purchase'),
#  (249, 5, 9, 'Album Purchase'),
#  (250, 11, 14, 'Album Purchase'),
#  (251, 1, 1, 'Non Album Purchase'),
#  (252, 1, 2, 'Non Album Purchase'),
#  (253, 1, 2, 'Non Album Purchase'),
#  (254, 1, 4, 'Album Purchase'),
#  (255, 3, 6, 'Album Purchase'),
#  (256, 5, 9, 'Album Purchase'),
#  (257, 10, 14, 'Album Purchase'),
#  (258, 1, 1, 'Non Album Purchase'),
#  (259, 1, 2, 'Non Album Purchase'),
#  (260, 1, 2, 'Non Album Purchase'),
#  (261, 2, 4, 'Non Album Purchase'),
#  (262, 4, 6, 'Non Album Purchase'),
#  (263, 7, 9, 'Non Album Purchase'),
#  (264, 8, 14, 'Album Purchase'),
#  (265, 1, 1, 'Non Album Purchase'),
#  (266, 1, 2, 'Non Album Purchase'),
#  (267, 2, 2, 'Non Album Purchase'),
#  (268, 1, 4, 'Album Purchase'),
#  (269, 3, 6, 'Album Purchase'),
#  (270, 6, 9, 'Album Purchase'),
#  (271, 9, 14, 'Album Purchase'),
#  (272, 1, 1, 'Non Album Purchase'),
#  (273, 1, 2, 'Non Album Purchase'),
#  (274, 1, 2, 'Non Album Purchase'),
#  (275, 1, 4, 'Album Purchase'),
#  (276, 3, 6, 'Album Purchase'),
#  (277, 5, 9, 'Album Purchase'),
#  (278, 10, 14, 'Album Purchase'),
#  (279, 1, 1, 'Non Album Purchase'),
#  (280, 1, 2, 'Non Album Purchase'),
#  (281, 1, 2, 'Non Album Purchase'),
#  (282, 3, 4, 'Non Album Purchase'),
#  (283, 3, 6, 'Album Purchase'),
#  (284, 5, 9, 'Album Purchase'),
#  (285, 10, 14, 'Album Purchase'),
#  (286, 1, 1, 'Non Album Purchase'),
#  (287, 2, 2, 'Non Album Purchase'),
#  (288, 1, 2, 'Non Album Purchase'),
#  (289, 1, 4, 'Album Purchase'),
#  (290, 4, 6, 'Non Album Purchase'),
#  (291, 6, 9, 'Album Purchase'),
#  (292, 10, 14, 'Album Purchase'),
#  (293, 1, 1, 'Non Album Purchase'),
#  (294, 1, 2, 'Non Album Purchase'),
#  (295, 1, 2, 'Non Album Purchase'),
#  (296, 1, 4, 'Album Purchase'),
#  (297, 2, 6, 'Album Purchase'),
#  (298, 4, 9, 'Album Purchase'),
#  (299, 8, 14, 'Album Purchase'),
#  (300, 1, 1, 'Non Album Purchase'),
#  (301, 1, 2, 'Non Album Purchase'),
#  (302, 1, 2, 'Non Album Purchase'),
#  (303, 1, 4, 'Album Purchase'),
#  (304, 3, 6, 'Album Purchase'),
#  (305, 5, 9, 'Album Purchase'),
#  (306, 10, 14, 'Album Purchase'),
#  (307, 1, 1, 'Non Album Purchase'),
#  (308, 1, 2, 'Non Album Purchase'),
#  (309, 1, 2, 'Non Album Purchase'),
#  (310, 1, 4, 'Album Purchase'),
#  (311, 2, 6, 'Album Purchase'),
#  (312, 5, 9, 'Album Purchase'),
#  (313, 9, 14, 'Album Purchase'),
#  (314, 1, 1, 'Non Album Purchase'),
#  (315, 2, 2, 'Non Album Purchase'),
#  (316, 2, 2, 'Non Album Purchase'),
#  (317, 4, 4, 'Non Album Purchase'),
#  (318, 4, 6, 'Non Album Purchase'),
#  (319, 8, 9, 'Non Album Purchase'),
#  (320, 11, 14, 'Album Purchase'),
#  (321, 1, 1, 'Non Album Purchase'),
#  (322, 1, 2, 'Non Album Purchase'),
#  (323, 2, 2, 'Non Album Purchase'),
#  (324, 1, 4, 'Album Purchase'),
#  (325, 3, 6, 'Album Purchase'),
#  (326, 4, 9, 'Album Purchase'),
#  (327, 10, 14, 'Album Purchase'),
#  (328, 1, 1, 'Non Album Purchase'),
#  (329, 1, 2, 'Non Album Purchase'),
#  (330, 1, 2, 'Non Album Purchase'),
#  (331, 1, 4, 'Album Purchase'),
#  (332, 2, 6, 'Album Purchase'),
#  (333, 3, 9, 'Album Purchase'),
#  (334, 10, 14, 'Album Purchase'),
#  (335, 1, 1, 'Non Album Purchase'),
#  (336, 1, 2, 'Non Album Purchase'),
#  (337, 1, 2, 'Non Album Purchase'),
#  (338, 1, 4, 'Album Purchase'),
#  (339, 3, 6, 'Album Purchase'),
#  (340, 4, 9, 'Album Purchase'),
#  (341, 12, 14, 'Non Album Purchase'),
#  (342, 1, 1, 'Non Album Purchase'),
#  (343, 1, 2, 'Non Album Purchase'),
#  (344, 1, 2, 'Non Album Purchase'),
#  (345, 1, 4, 'Album Purchase'),
#  (346, 3, 6, 'Album Purchase'),
#  (347, 5, 9, 'Album Purchase'),
#  (348, 10, 14, 'Album Purchase'),
#  (349, 1, 1, 'Non Album Purchase'),
#  (350, 1, 2, 'Non Album Purchase'),
#  (351, 1, 2, 'Non Album Purchase'),
#  (352, 2, 4, 'Non Album Purchase'),
#  (353, 2, 6, 'Album Purchase'),
#  (354, 4, 9, 'Album Purchase'),
#  (355, 11, 14, 'Album Purchase'),
#  (356, 1, 1, 'Non Album Purchase'),
#  (357, 1, 2, 'Non Album Purchase'),
#  (358, 1, 2, 'Non Album Purchase'),
#  (359, 2, 4, 'Non Album Purchase'),
#  (360, 3, 6, 'Album Purchase'),
#  (361, 6, 9, 'Album Purchase'),
#  (362, 10, 14, 'Album Purchase'),
#  (363, 1, 1, 'Non Album Purchase'),
#  (364, 1, 2, 'Non Album Purchase'),
#  (365, 1, 2, 'Non Album Purchase'),
#  (366, 2, 4, 'Non Album Purchase'),
#  (367, 3, 6, 'Album Purchase'),
#  (368, 6, 9, 'Album Purchase'),
#  (369, 9, 14, 'Album Purchase'),
#  (370, 1, 1, 'Non Album Purchase'),
#  (371, 1, 2, 'Non Album Purchase'),
#  (372, 2, 2, 'Non Album Purchase'),
#  (373, 1, 4, 'Album Purchase'),
#  (374, 2, 6, 'Album Purchase'),
#  (375, 5, 9, 'Album Purchase'),
#  (376, 10, 14, 'Album Purchase'),
#  (377, 1, 1, 'Non Album Purchase'),
#  (378, 1, 2, 'Non Album Purchase'),
#  (379, 1, 2, 'Non Album Purchase'),
#  (380, 2, 4, 'Non Album Purchase'),
#  (381, 2, 6, 'Album Purchase'),
#  (382, 5, 9, 'Album Purchase'),
#  (383, 10, 14, 'Album Purchase'),
#  (384, 1, 1, 'Non Album Purchase'),
#  (385, 1, 2, 'Non Album Purchase'),
#  (386, 2, 2, 'Non Album Purchase'),
#  (387, 1, 4, 'Album Purchase'),
#  (388, 4, 6, 'Non Album Purchase'),
#  (389, 5, 9, 'Album Purchase'),
#  (390, 10, 14, 'Album Purchase'),
#  (391, 1, 1, 'Non Album Purchase'),
#  (392, 1, 2, 'Non Album Purchase'),
#  (393, 1, 2, 'Non Album Purchase'),
#  (394, 1, 4, 'Album Purchase'),
#  (395, 2, 6, 'Album Purchase'),
#  (396, 6, 9, 'Album Purchase'),
#  (397, 9, 14, 'Album Purchase'),
#  (398, 1, 1, 'Non Album Purchase'),
#  (399, 1, 2, 'Non Album Purchase'),
#  (400, 1, 2, 'Non Album Purchase'),
#  (401, 1, 4, 'Album Purchase'),
#  (402, 2, 6, 'Album Purchase'),
#  (403, 4, 9, 'Album Purchase'),
#  (404, 7, 14, 'Album Purchase'),
#  (405, 1, 1, 'Non Album Purchase'),
#  (406, 1, 2, 'Non Album Purchase'),
#  (407, 1, 2, 'Non Album Purchase'),
#  (408, 1, 4, 'Album Purchase'),
#  (409, 3, 6, 'Album Purchase'),
#  (410, 4, 9, 'Album Purchase'),
#  (411, 9, 14, 'Album Purchase'),
#  (412, 1, 1, 'Non Album Purchase')]

# %% [markdown]
# ### Category: Not an Album Purchase

# %% [markdown]
# Here we calculate the Percentage of Non Album Purchases for the company.

# %%
# %%sql
#
# WITH com_prchs AS
# (SELECT il.InvoiceId invoice_id, il.TrackId Pur_tracks, t.AlbumId album_id
#   FROM tracks t
# INNER JOIN invoice_items il ON il.TrackId = t.TrackId
# ORDER BY 1
# ),
#
# ctgr_prchs AS
# (SELECT invoice_id, COUNT(DISTINCT(album_id)) Distinct_album_id,
#        COUNT(album_id) No_of_album_id,
#        CASE
#        WHEN COUNT(album_id) - COUNT(DISTINCT(album_id)) <= 2 THEN "Non Album Purchase"
#        ELSE "Album Purchase"
#        END AS Category
#   FROM com_prchs
# GROUP BY 1
# )
#
# SELECT (SELECT MAX(InvoiceId)
#           FROM invoice_items) TOTAL_invoice_id,
#        COUNT(invoice_id) No_of_invoice_id,
#        (SELECT ROUND(CAST(COUNT(invoice_id) AS FLOAT) * 100 / (SELECT MAX(invoice_id)
#                                             FROM invoice_items), 2)) Perc_invoice
#   FROM ctgr_prchs
# WHERE Category = "Non Album Purchase";
# Out:
#  * sqlite:///chinook.db
# Done.
# [(412, 213, 51.7)]

# %% [markdown]
# From the above table, it can be seen that nearly half of the purchases, i.e., 213 out of 412 are Non Album Purchase.

# %% [markdown]
# ### Category: Album Purchase

# %% [markdown]
# Here we calculate the Percentage of Album Purchase for the company.

# %%
# %%sql
#
# WITH com_prchs AS
# (SELECT il.InvoiceId invoice_id, il.TrackId Pur_tracks, t.AlbumId album_id
#   FROM tracks t
# INNER JOIN invoice_items il ON il.TrackId = t.TrackId
# ORDER BY 1
# ),
#
# ctgr_prchs AS
# (SELECT invoice_id, COUNT(DISTINCT(album_id)) Distinct_album_id,
#        COUNT(album_id) No_of_album_id,
#        CASE
#        WHEN COUNT(album_id) - COUNT(DISTINCT(album_id)) <= 2 THEN "Non Album Purchase"
#        ELSE "Album Purchase"
#        END AS Category
#   FROM com_prchs
# GROUP BY 1
# )
#
# SELECT (SELECT MAX(InvoiceId)
#           FROM invoice_items) TOTAL_invoice_id,
#        COUNT(invoice_id) No_of_invoice_id,
#        (SELECT ROUND(CAST(COUNT(invoice_id) AS FLOAT) * 100 / (SELECT MAX(invoice_id)
#                                             FROM invoice_items), 2)) Perc_invoice
#   FROM ctgr_prchs
# WHERE Category = "Album Purchase";
# Out:
#  * sqlite:///chinook.db
# Done.
# [(412, 199, 48.42)]

# %% [markdown]
# Here, it can be seen that nearly 48%, i.e., 199 out of 412 purchase are Album Purchases.

# %% [markdown]
# From the above two intepretations, it can be seen that Non Album Purchases slightly sell better. The store should consider buying popular tracks from albums rather than buying the whole album.
